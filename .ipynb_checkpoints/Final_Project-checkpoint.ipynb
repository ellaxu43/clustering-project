# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import env
import dataprep

from scipy import stats
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression 
from math import sqrt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import math


from sklearn.model_selection import train_test_split
import sklearn.linear_model
import sklearn.feature_selection
import sklearn.preprocessing
from scipy import stats
from sklearn.feature_selection import SelectKBest, RFE, f_regression, SequentialFeatureSelector
from sklearn.cluster import KMeans

# %% [markdown]
# # What is driving the log error in the Zestimates?

# %% [markdown]
# Ella Xu Junior Data Scientist | Zillow Data Science Team

# %% [markdown]
# ## Project Description
# Zillow has data on roughly 110 million homes across the United States.The company offers several features, including value estimates of homes, value changes of each home in a given time frame, aerial views of homes, and prices of comparable homes in the area. It also provides basic information on a given home, such as square footage and the number of bedrooms and bathrooms. Users can also get estimates of homes that have undergone significant changes, such as a remodeled kitchen.
#
# As the most visited real estate website in the United States, Zillow and its affiliates provide customers with an on-demand experience selling, buying, leasing and financing with a transparent and near-seamless end-to-end service. However, as we all know, the real estate market is constantly volatile and changing.
#
# Zillow's Zestimate is an estimate of value using a proprietary formula created by the online real estate database company. Zestimates cover more than 100 million homes across the United States. A Zestimate is calculated from physical attributes, tax records, and user submitted data

# %% [markdown]
# # Goals

# %% [markdown]
# Using 2017 properties and prediction data from our Zillow database for single unit/single family homes, we were tasking with improving the log error (Zestimate). We will be using the Clustering Algorithm KMeans to find clusters within the data to improve our estimate of the log error.I will create Regression models to predict logerror and find the key drivers.

# %% [markdown]
# # Planning

# %% [markdown]
# * Setup my repository environment (.gitignore, README.md)
# * Import and test my wrangle functions.
# * Define test for at least two hypotheses.
# * Explore and create clusters.
# * Train and evalurate four different regression models.
# * Report my conclusions and next steps in a presentation.

# %% [markdown]
# # Executive Summary

# %% [markdown]
# There is a relationship between tax_value, square feet, and bedroom count in predicting the logerror of single family units. Bedrooms and tax value cluster were shown as the very useful combination.
#
# My polynomial Model on test dataset had a Root Mean Squared Error (RMSE) of 0.167.

# %% [markdown]
# ## Acquiring the Data
# To acquire the Zillow data, I used the zillow database in the Codeup SQL server, and selected the requested columns. I then selected only Single Family Residential and Inferred Single Family Residential from the 2017 properties.

# %%
df = dataprep.get_zillow_data()
df = dataprep.wrangle_zillow() 
df.head()
# Out:
# Using cached csv
#    bathrooms  bedrooms    area    fips    latitude    longitude  \
# 0        3.5       4.0  3100.0  6059.0  33634931.0 -117869207.0
# 1        1.0       2.0  1465.0  6111.0  34449266.0 -119281531.0
# 2        2.0       3.0  1243.0  6059.0  33886168.0 -117823170.0
# 3        3.0       4.0  2376.0  6037.0  34245180.0 -118240722.0
# 4        3.0       3.0  1312.0  6037.0  34185120.0 -118414640.0
#
#    lotsizesquarefeet  regionidcounty  regionidzip  year_built  tax_value  \
# 0             4506.0          1286.0      96978.0      1998.0  1023282.0
# 1            12647.0          2061.0      97099.0      1967.0   464000.0
# 2             8432.0          1286.0      97078.0      1962.0   564778.0
# 3            13038.0          3101.0      96330.0      1970.0   145143.0
# 4           278581.0          3101.0      96451.0      1964.0   119407.0
#
#    taxamount  logerror
# 0   11013.72  0.025595
# 1    5672.48  0.055619
# 2    6488.30  0.005383
# 3    1777.51 -0.103410
# ...

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# * Drop columns with more than 30% of nulls values.
#
# * Restrict dataset to only properties that meet single unit use criteria.
#
# * Restrict dataset to only those properties with at least 1 bath & bed and 350 sqft area.
#
# * Replace nulls with median values for select columns.
#
# * Remove outliers for 'bathrooms','bedrooms','area', and 'lotsize'.
#             Find the first quartile, Q1.
#             Find the third quartile, Q3.
#             Calculate the IQR. IQR= Q3-Q1.
#             Define the normal data range with lower limit as Q1–1.5*IQR and upper limit as Q3+1.5*IQR.
#
# * Rename columns to make it easy to read.
#
# * Split the data 80/20 train test. 70/30 on train validate split.

# %%
train, validate,test = dataprep.removed_outliers(df)
#Now import the train, validate and test function from dataprep.py

# %%
print(train.shape)
print(validate.shape)
print(test.shape)
#print out the shape of the train, validate and test to double check.
# Out:
# (30852, 13)
# (13223, 13)
# (11019, 13)

# %% [markdown]
# ## Explore the Train dataset
# Initial Questions:
#
# What's the distribution of the logerror?
#
# What are the correlation coefficients between variables?
#
# What areas are we focusing on?
#
# Does year built impact logerror?
#
# Does bedroom count impact logerror?
#
# Does bathroom count impact logerror?

# %% [markdown]
# ### What's the distribution of the logerror?

# %%
#Plot again on the overall logerror distribution 
plt.figure(figsize=(15, 8)) #figure size
sns.distplot(df.logerror) #tell sns the feature that we would like to plot. 
plt.title('Log Error Distribution', fontsize=20)#set up the title 
plt.xlabel('Log Error')#set up the x label. 
plt.show()
print("Takeawys: most of our log error are between -1 - 1. ")
print(f'The min of logerror {df.logerror.min()}')
print(f'The max of logerror {df.logerror.max()}')
print(f'The mean of logerror {df.logerror.mean()}')
# Out:
# Takeawys: most of our log error are between -1 - 1.
# The min of logerror -4.65542037764
# The max of logerror 3.39454406516
# The mean of logerror 0.016633031152871233

# %% [markdown]
# ### What are the correlation coefficients between variables?

# %%
# Heatmap to display correlation of the features and logerror.
plt.figure(figsize=(14, 10))# set up the figure size. 
sns.heatmap(train.corr(), cmap='Blues', annot=True)# set up the heatmap, including color and annot. 
plt.title('Correlation Heatmap of All Features Including the Target', fontsize=20) # set upt the title and front size 
plt.show()

# %% [markdown]
# ***Takeaways: The heatmap doesn't show any particulary high linear correlation but there could still be certain features that have more of an impact on the target variable.***

# %% [markdown]
# ### What areas are we focusing on?

# %%
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
#first import the library.

# %%
# Extract the data we're interested in, reset the original longtitude and latitude by /100000
train.latitude = train.latitude/1000000
train.longtitude = train.longitude/1000000

# %%
# 1. Draw the map background
fig = plt.figure(figsize=(8, 8)) #set the gig size.
m = Basemap(projection='gnom', resolution='c', 
            lat_0=35, lon_0=-119,
            width=0.7E6, height=0.5E6) #set up the x, y and width and height. 
m.shadedrelief()
m.drawcoastlines(color='gray') 
m.drawcountries(color='gray')
m.drawstates(color='gray')#design this map. 
m.scatter(train.longtitude, train.latitude, latlon=True,
          cmap='Reds', alpha=0.3)
x, y = m(-118.2437, 34.0522) #google the LA location and mark it on the map. 
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Los Angeles', fontsize=12);
x2, y2 = m(-117.8311, 33.7175)
plt.plot(x2, y2, 'ok', markersize=5)#google the orange county and mark it on the map. 
plt.text(x2, y2, ' Orange', fontsize=12);
x3, y3 = m(-119.1391, 34.3705)
plt.plot(x3, y3, 'ok', markersize=5)
plt.text(x3, y3, 'Ventura', fontsize=12);
x4, y4 = m(-118, 34.7)#goodle the ventura couty and mark it on the map. 
plt.plot(x4, y4, 'ok', markersize=5)
plt.text(x4, y4, ' Los Angeles', fontsize=12);#LA is big, including the north area, also mark it. 
plt.title("The Area We're Focusing On", fontsize=18)#Add title to this plot.
# Out:
# Text(0.5, 1.0, "The Area We're Focusing On")

# %% [markdown]
# ***Takeaways: Ventura, Los Angeles and Orange are three couties we are focusing on.***

# %% [markdown]
# ### Does the area of a home impact on logerror?

# %%
#Plot data and a linear regression model fit the area and logerror. 
plt.figure(figsize=(12,7))#set up the figure size.
sns.regplot(x=train.area, y=train.logerror, x_bins=20,ci=80, color = 'g')
# regplot can use on continuous feature by creating couple bins, 
#CI is  Size of the confidence interval for the regression estimate.I set to 80%, just to take a look the overall trend. 
plt.xlabel('Area')# set up the x axis. 
plt.ylabel('Log Error')# set up the y axis
plt.title('Does the area of homes impact on logerror?',fontsize=15) # set up the title and fontsize. 
mean1 = train.logerror.mean()# draw the mean of the logerror. 
plt.axhline(mean1, ls='--', color='red')#set the color to red, and line style. 
plt.show()

# %% [markdown]
# Looks like there is a linear relationship between area and logerror, let's run a test to further approve it.

# %% [markdown]
# Hypothesis Testing

# %%
#H0:There is no relationship between logerror and area.
#H1:There is relationship between logerror and area.

# %%
alpha = 0.05 #set the appha to 0.05
# Perform a corr test because both features are continuous features. 
corr, p = stats.pearsonr(train.logerror, train.area)
print(corr, p) #print corr and p value. 
if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# 0.024297243538087994 1.9705294222733503e-05
# We reject the null hypothesis

# %% [markdown]
# ***Takeaways: We have confidence to say there is a linear relationship between area and logerror.***

# %% [markdown]
# ### Does bedroom count impact log error?

# %%
# let's plt it to check it out. 
plt.figure(figsize=(12,7))#set up the figure size
sns.set_palette(sns.color_palette("rocket_r")) #set the palette style. 
#with sns.color_palette("Blues"):
sns.barplot(x='bedrooms', y='logerror', data=train) #let's create a barplot!
plt.xlabel('Bedroom Count')# label the x axis.
plt.ylabel('Log Error')#label the y axis. 
plt.title('Does bedroom count impact log error?',fontsize=15)#set up the title.
mean1 = train.logerror.mean()#add mean of the logerror to this plt.
plt.axhline(mean1, ls='--', color='red')# set the mean line style. 

plt.show()#show the plt

# %% [markdown]
# ***Looks like homes with less bedrooms counts tend to produce smaller log error, homes with 5 and 6 bedrooms counts have highest logerror. Let's run a t test to compare.***

# %% [markdown]
# Hypothesis Testing

# %%
# H0: Logerror for homes with 1,2,3 bedrooms == homes with 4,5,6 bedrooms. 
# H1: Logerror for homes with 1,2,3 bedrooms != homes with 4,5,6 bedrooms.

# %%
#create subsets to use t test. 
less_bedrooms = train[(train.bedrooms <=3)].logerror
more_bedrooms = train[(train.bedrooms > 3)].logerror 

# Perform a t test becuase we are comparsing two means,
# This is a two-sampled, two-tailed test. 
t, p = stats.ttest_ind(less_bedrooms,more_bedrooms, equal_var=False )
print(t, p)
if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# -3.6950301277802056 0.00022061957122440358
# We reject the null hypothesis

# %% [markdown]
# ***Takeaways: We have confidence to say that homes with less bedroom counts tend to produce smaller log error.***

# %% [markdown]
# ### Does bathroom count impact logerror?

# %%
# let's plt it to check it out. 
plt.figure(figsize=(12,7))#set up the figure size
sns.set_palette(sns.color_palette("rocket_r")) #set the palette style. 
#with sns.color_palette("Blues"):
sns.barplot(x='bathrooms', y='logerror', data=train) #let's create a barplot!
plt.xlabel('Bathrooms Count')# label the x axis.
plt.ylabel('Log Error')#label the y axis. 
plt.title('Does bathroom count impact log error?',fontsize=15)#set up the title.
mean1 = train.logerror.mean()#add mean of the logerror to this plt.
plt.axhline(mean1, ls='--', color='red')# set the mean line style. 

plt.show()#show the plt

# %% [markdown]
# ***Looks like homes with less bathrooms counts tend to produce smaller log error, homes with 3.5 and 4 bathroom counts have highest logerror. Let's run a t test to compare.***

# %% [markdown]
# Hypothesis Testing

# %%
# H0: Logerror for homes with 1,2,3 bathrooms == homes with 4,5,6 bathrooms. 
# H1: Logerror for homes with 1,2,3 bathrooms != homes with 4,5,6 bathrooms.

# %%
alpha = 0.5
#create subsets to use t test. 
less_bathrooms = train[(train.bathrooms <=2)].logerror
more_bathrooms = train[(train.bathrooms >= 2.5)].logerror 

# Perform a t test becuase we are comparsing two means,
# This is a two-sampled, two-tailed test. 
t, p = stats.ttest_ind(less_bathrooms,less_bathrooms, equal_var=False ) 
if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# We fail to reject the null hypothesis

# %% [markdown]
# ***Takeaways: We don't have confidence to say that homes with less bathroom counts tend to produce smaller log error.***

# %% [markdown]
# ###  Does year built impact logerror?

# %%
#H0:There is no relationship between logerror and year_built.
#H1: There is relationship between logerror and year_built.

# %%
#first, we can create a scatterplot to see the distribution.  
plt.figure(figsize=(12,7)) # set up the figure size. 
sns.scatterplot(x='year_built', y='logerror', data=train,alpha=.3, color ='brown')# set up the x and y. 

mean1 = train.logerror.mean()# draw a logerror mean line 
plt.axhline(mean1, ls='--', color='grey')# set up the color and style

plt.xlabel('Year_built') # lable x 
plt.ylabel('Log Error')# lable y
plt.title('Does year_built related with logerror?',fontsize=15)# add title and set up fontsize. 
plt.show()

# %% [markdown]
# I'm unable to see the relationship between year built and logerror, so I will run a test.

# %%
# Perform a corr test because both features are continuous features. 
alpha = 0.05 # set up the alpha = 0.05 as normal. 
corr, p = stats.pearsonr(train.logerror, train.year_built)
print(corr, p)

if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# 0.0037538637399333746 0.4694022007481412
# We fail to reject the null hypothesis

# %% [markdown]
# ***Takeaways: We can't say that year_built are related with logerror, or in other words, there is no linear relationship between year_built and logerror.***

# %% [markdown]
# ### Summaries:
# * Ventura, Los Angeles and Orange are three couties we are focusing on.
#
# * We have confidence to say there is a linear relationship between area and logerror.
#
# * We have confidence to say that homes with less bedrooms counts tend to produce smaller log error.
#
# * There is no linear relationship between year_built and logerror.
#
# * Log error is not impacted by the number of bathrooms.
#
# ### From the exploration above, log error is affected by bedrooms and area but not affected by bathrooms and year built.

# %% [markdown]
# ## Clustering Exploration

# %% [markdown]
# Clustering is the task of dividing the population or data points into a number of groups such that data points in the same groups are more similar to other data points in the same group than those in other groups. In simple words, the aim is to segregate groups with similar traits and assign them into clusters.

# %%
train=train.drop(columns=['latitude',
       'longitude',"regionidzip",'regionidcounty','fips'])
validate = validate.drop(columns=['latitude',
       'longitude',"regionidzip",'regionidcounty','fips'])
test =test.drop(columns=['latitude',
       'longitude',"regionidzip",'regionidcounty','fips'])
#droped latitude,longtitude, regionidzip... any feature that represent location, because I have run an different
#analysis, shows the logerror in different counties has no significant difference.

# %%
## Scale our data. Columns that are suitble for scalling are, bedrooms, bathrooms, area, and home_age. 
def scale_data(train, validate, test, return_scaler=False):
    '''
    Scales the 3 data splits.
    
    takes in the train, validate, and test data splits and returns their scaled counterparts.
    
    If return_scaler is true, the scaler object will be returned as well.
    '''
    columns_to_scale = ['bathrooms', 'bedrooms', 'area',  'lotsizesquarefeet', 
        
       'year_built',  'tax_value', 'taxamount']
    #These columns are continuous features, suitble to scale. 
    train_scaled = train
    validate_scaled = validate
    test_scaled = test
    # create copy to avoid overwrite. 
    
    scaler = sklearn.preprocessing.MinMaxScaler() # import the min max scaler method. 
    scaler.fit(train[columns_to_scale]) # fit the data
    
    train_scaled[columns_to_scale] = scaler.transform(train[columns_to_scale]) #transform our data
    validate_scaled[columns_to_scale] = scaler.transform(validate[columns_to_scale])
    test_scaled[columns_to_scale] = scaler.transform(test[columns_to_scale])
    #transform to scaled dataset. 
    
    if return_scaler:
        return scaler, train_scaled, validate_scaled, test_scaled
    else:
        return train_scaled, validate_scaled, test_scaled

# %%
train_scaled, validate_scaled, test_scaled = scale_data(train, validate, test)
#let's input our train validate and test data, and transform them all to scaled data.

# %% [markdown]
# ## First cluster groups according to area and lotsize.

# %%
cols = ['area','lotsizesquarefeet']
X = cols #first assign X,the cols.

# %%
inertias = {} 
#evaluate best k using elbow method and analyzing the change in sse.

for k in range(2, 11): 
    #2-11 is a wide range for k. 
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(train_scaled[X])
    inertias[k] = kmeans.inertia_  
    #create kmeans object & fit using training data.
pd.Series(inertias).plot(xlabel='k', ylabel='Inertia', figsize=(13, 7))#set up the x label and y label
plt.grid()#show the grid

# %%
kmeans = KMeans(n_clusters=4).fit(train_scaled[X])#create kmeans object & fit using training data.
#let's go with 4.

# %%
#make predictions on train, validate and test. 
train_scaled['area_lot_cluster'] = kmeans.predict(train_scaled[X])
validate_scaled['area_lot_cluster'] = kmeans.predict(validate_scaled[X])
test_scaled['area_lot_cluster'] = kmeans.predict(test_scaled[X])
#Label observations with cluster id and append centroid values to each X dataframe.
train_scaled.area_lot_cluster = train_scaled.area_lot_cluster.astype('category')# set the cluster type as category. 
train_scaled.head()
# Out:
#        bathrooms  bedrooms      area    fips  lotsizesquarefeet  \
# 28396   0.666667       0.4  0.780522  6037.0           0.534453
# 27211   0.000000       0.2  0.299130  6037.0           0.380539
# 14282   0.500000       0.2  0.250435  6059.0           0.448621
# 4728    0.000000       0.4  0.236522  6037.0           0.443043
# 25835   0.333333       0.4  0.504000  6037.0           0.675055
#
#        rawcensustractandblock  year_built  structuretaxvaluedollarcnt  \
# 28396                0.010950    0.793893                    0.077161
# 27211                0.001605    0.305344                    0.059632
# 14282                0.296733    0.854962                    0.046208
# 4728                 0.010955    0.664122                    0.025124
# 25835                0.010826    0.816794                    0.068022
#
#        tax_value  landtaxvaluedollarcnt  taxamount  logerror area_lot_cluster
# 28396   0.058725               0.014854   0.086524 -0.007491                2
# ...

# %%
plt.figure(figsize=(12,6))
#set up the figsize.
sns.relplot(data=train_scaled, y='area', x='lotsizesquarefeet', hue='area_lot_cluster')
#set up the x and y, hue is the cluster that we just created. 
#use a replot to visual the cluster. 
plt.xlabel('Lot Size') 
# lable x 
plt.ylabel('Area')
# lable y
plt.title('Lot and area cluster',fontsize=15)
# add title and set up fontsize. 
plt.show()

# %% [markdown]
# Takeaways: four clusters are based on lot size and area size.

# %%
plt.figure(figsize=(12,6))#set up the figsize. 
plt.scatter(y=train_scaled.logerror, x=train_scaled.lotsizesquarefeet, c=train_scaled.area_lot_cluster, alpha=.7)
#same as replot, we use a scatter plt this time. 
plt.yscale('symlog')#ysmlog means symmetrical log, and allows positive and negative values.
#symlog allows to set a range around zero within the plot will be linear instead of logarithmic.
plt.xlabel('Finished Square Feet') #mark the x 
plt.ylabel('Log Error of Zestimate')#mark the y
plt.title('Is there distinction between clusters when visualizing lotsize by the error in zestimate?')
#add the title. 
plt.show()

# %% [markdown]
# I don't see anything that stands out.Let's run a test to further investigate.

# %%
#H0: Area and lotsize cluster has no on impact on logerror. 
#H1: Area and lotsize cluster has impact on logerror.

# %%
#create subset to set up statstic test.
cluster1 = train_scaled[(train_scaled.area_lot_cluster == 0)].logerror
cluster2 = train_scaled[(train_scaled.area_lot_cluster == 1)].logerror 
cluster3 = train_scaled[(train_scaled.area_lot_cluster == 2)].logerror
cluster4 = train_scaled[(train_scaled.area_lot_cluster == 4)].logerror

# %%
alpha = 0.05
# ANOVA, is a statistical method that separates observed variance data into 
#different components to use for additional tests. A one-way ANOVA is used for three or more groups of data, 
#to gain information about the relationship between the dependent and independent variables.
f, p = stats.f_oneway(cluster1 ,cluster2,cluster3,cluster4)
f, p

if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# We fail to reject the null hypothesis

# %% [markdown]
# ***Takeaways: We can't say that area and lotsize cluster are related with logerror.***

# %% [markdown]
# ## Second cluster groups according to year_built and tax_value.

# %%
cols = ['year_built',
       'tax_value']
#let's try the year built and tax value. 
X= cols
#evaluate best k using elbow method and analyzing the change in sse.

inertias = {}

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(train_scaled[X])
    #fit the kmeans.
    inertias[k] = kmeans.inertia_
    #apply inertias.

pd.Series(inertias).plot(xlabel='k', ylabel='Inertia', figsize=(13, 7))
plt.grid()
#print out the grid.

# %%
kmeans = KMeans(n_clusters=4).fit(train_scaled[X])
#Went with a k of 4

# %%
#make predictions on train, validate and test. 
train_scaled['year_tax_cluster'] = kmeans.predict(train_scaled[X])
train_scaled.year_tax_cluster = train_scaled.year_tax_cluster.astype('category')
train_scaled.head()
# Out:
#        bathrooms  bedrooms      area  lotsizesquarefeet  year_built  \
# 5518    0.000000       0.2  0.260174           0.629751    0.421053
# 29785   0.000000       0.0  0.100174           0.441577    0.789474
# 18346   0.666667       0.6  0.715130           0.441577    0.962406
# 6443    0.333333       0.6  0.314087           0.359913    0.548872
# 1435    0.333333       0.4  0.495652           0.441577    0.684211
#
#        tax_value  taxamount  logerror year_tax_cluster
# 5518    0.008691   0.014790 -0.051970                3
# 29785   0.020305   0.023167  0.068618                2
# 18346   0.144719   0.217854  0.006409                1
# 6443    0.048596   0.052772 -0.018135                0
# 1435    0.136860   0.120268  0.046290                2

# %%
plt.figure(figsize=(12,6))
# plt.scatter(y=X_train.latitude, x=X_train.longitude, c=X_train.area_cluster, alpha=.4)
plt.scatter(y=train.logerror, x=train.tax_value, c=train.year_tax_cluster, alpha=.7)
plt.yscale('symlog')#ysmlog means symmetrical log, and allows positive and negative values.
#symlog allows to set a range around zero within the plot will be linear instead of logarithmic.

plt.xlabel('Tax_value')#mark the x axis. 
plt.ylabel('Log Error of Zestimate')
plt.title('Is there distinction between clusters when visualizing tax value by the error in zestimate?')
plt.show()

# %% [markdown]
# Takeaways: four clusters are based on lot size and area size. I don't see anything that stands out.Let's run a test to further investigate.

# %%
#H0: Year built and tax_value cluster has no on impact on logerror. 
#H1: Year built and tax_value cluster has impact on logerror.

# %%
#create subset to set up statstic test.
cluster1 = train_scaled[(train_scaled.year_tax_cluster == 0)].logerror
cluster2 = train_scaled[(train_scaled.year_tax_cluster == 1)].logerror 
cluster3 = train_scaled[(train_scaled.year_tax_cluster == 2)].logerror
cluster4 = train_scaled[(train_scaled.year_tax_cluster == 4)].logerror

# %%
alpha = 0.05
# ANOVA, is a statistical method that separates observed variance data into 
#different components to use for additional tests. A one-way ANOVA is used for three or more groups of data, 
#to gain information about the relationship between the dependent and independent variables.
f, p = stats.f_oneway(cluster1 ,cluster2,cluster3,cluster4)
f, p

if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# We fail to reject the null hypothesis

# %% [markdown]
# ***Takeaways: We can't say that tax_value and year_built cluster are related with logerror.***

# %% [markdown]
# ## Third Cluster groups according to bedrooms  and tax_value.

# %%
cols = ['bedrooms',
       'tax_value']
X= cols
inertias = {}
#evaluate best k using elbow method and analyzing the change in sse.

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    #set the k range to 2-11. 
    #fit the kmeans.
    kmeans.fit(train_scaled[X])
    inertias[k] = kmeans.inertia_

pd.Series(inertias).plot(xlabel='k', ylabel='Inertia', figsize=(13, 7))
plt.grid()

# %%
kmeans = KMeans(n_clusters=3).fit(train_scaled[X])
#Went with a k of 3

# %%
#make predictions on train, validate and test. 
train_scaled['bed_tax_cluster'] = kmeans.predict(train_scaled[X])
validate_scaled['bed_tax_cluster'] = kmeans.predict(validate_scaled[X])
test_scaled['bed_tax_cluster'] = kmeans.predict(test_scaled[X])

train_scaled.bed_tax_cluster = train_scaled.bed_tax_cluster.astype('category')
train_scaled.head()
# Out:
#        bathrooms  bedrooms      area  lotsizesquarefeet  year_built  \
# 5518    0.000000       0.2  0.260174           0.629751    0.421053
# 29785   0.000000       0.0  0.100174           0.441577    0.789474
# 18346   0.666667       0.6  0.715130           0.441577    0.962406
# 6443    0.333333       0.6  0.314087           0.359913    0.548872
# 1435    0.333333       0.4  0.495652           0.441577    0.684211
#
#        tax_value  taxamount  logerror bed_tax_cluster
# 5518    0.008691   0.014790 -0.051970               1
# 29785   0.020305   0.023167  0.068618               1
# 18346   0.144719   0.217854  0.006409               0
# 6443    0.048596   0.052772 -0.018135               0
# 1435    0.136860   0.120268  0.046290               2

# %%
sns.relplot(data=train_scaled,
            y='bedrooms', 
            x='tax_value', 
            hue='bed_tax_cluster')
#Use a relplot to reflect the cluster

# %% [markdown]
# Takeaways: Three clusters are based on tax values and bedrooms. Let's run a test!

# %%
#H0: bedrooms and tax_value cluster has no on impact on logerror. 
#H1: bedrooms and tax_value cluster has impact on logerror.

# %%
#create subset to set up statstic test.
cluster1 = train_scaled[(train_scaled.bed_tax_cluster == 0)].logerror
cluster2 = train_scaled[(train_scaled.bed_tax_cluster == 1)].logerror 
cluster3 = train_scaled[(train_scaled.bed_tax_cluster == 2)].logerror

# %%
alpha = 0.05
# ANOVA, is a statistical method that separates observed variance data into 
#different components to use for additional tests. A one-way ANOVA is used for three or more groups of data, 
#to gain information about the relationship between the dependent and independent variables.

f, p = stats.f_oneway(cluster1 ,cluster2,cluster3)
f, p
print(f, p)

if p < alpha:
    print("We reject the null hypothesis")

else:
    print("We fail to reject the null hypothesis")
# Out:
# 10.467550192211128 2.8545821377851973e-05
# We reject the null hypothesis

# %% [markdown]
# ***Takeaways: We have confidence to say tax_value and bedrooms cluster are related with logerror.***

# %% [markdown]
# Summaries from clustering exploration:
# * tax_value and bedrooms are the only useful cluster that we have found, will take it to our model.

# %% [markdown]
# ### Let's split the train, validate and test into x and y.

# %%
train_scaled.columns 
#Before, I decide which columns move forward, let's print out the columns we have right now.
# Out:
# Index(['bathrooms', 'bedrooms', 'area', 'lotsizesquarefeet', 'year_built',
#        'tax_value', 'taxamount', 'logerror'],
#       dtype='object')

# %%
#drop the values that we found not useful from exploration 
# and values that I haven't had the time to explore. 
train_scaled=train_scaled.drop(columns=["year_built", 'bathrooms','lotsizesquarefeet','taxamount'])
validate_scaled = validate_scaled.drop(columns=["year_built", 'bathrooms','lotsizesquarefeet','taxamount'])
test_scaled =test_scaled.drop(columns=["year_built", 'bathrooms','lotsizesquarefeet','taxamount'])
#move forward with bedrooms, area,tax_value and bed_tax_cluster.

# %%
#once we have scaled our data, then we will split out scaled data and ready for our model. 
X_train_scaled = train_scaled.drop(columns=['logerror'])
#Drop the tax_value because tax_value is our target variable. 
#Drop the county because I already hot encoded them. 
#Drop county_LA_county because, I encoded all county, even drop one columns make no difference. 
#Drop year_built because I created home age, and I can scale the home easier. 
X_validate_scaled = validate_scaled.drop(columns=['logerror'])
#duplicate the process on validate and test. 
X_test_scaled = test_scaled.drop(columns=['logerror'])

y_train = train[['logerror']]
#y_train only contains tax_value 
y_validate = validate[['logerror']]
#y_validate only contains tax_value 
y_test = test[['logerror']]
##y_test only contains tax_value

# %% [markdown]
# ## Modeling

# %% [markdown]
# Features that will move forward to models are below:
#
#     1. bedrooms
#     2. area
#     3. tax_value
#     4. bed_tax_cluster
#
#
# Create four models:
# * Linear Regression.
# * Polynomial
# * Decision Tree Regressor
# * Random Forest Regressor

# %% [markdown]
# ## Baseline Model

# %%
# We need y_train and y_validate to be dataframes to append the new columns with predicted values. 
y_train = pd.DataFrame(y_train)
y_validate = pd.DataFrame(y_validate)

# The Project specs told us to use mean for our baseline
# 1. Predict logerror using mean
logerror_mean = y_train.logerror.mean()

y_train['logerror_mean'] = logerror_mean
y_validate['logerror_mean'] = logerror_mean

# 2. RMSE of tax_value_pred_mean
rmse_train = mean_squared_error(y_train.logerror, y_train.logerror_mean) ** (0.5)
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.logerror_mean) ** (0.5)

#create a dataframe, input the result. 
metric_df = pd.DataFrame(data=[
            {
                'model': 'Baseline', 
                'RMSE_train': rmse_train,
                'RMSE_validate': rmse_validate
                }
            ])
metric_df #show the dataframe.
# Out:
#       model  RMSE_train  RMSE_validate
# 0  Baseline    0.160135       0.160054

# %% [markdown]
# ### LinearRegression (OLS)

# %%
#let's create a linear regression first. 
lm2 = LinearRegression()
lm2.fit(X_train_scaled, y_train.logerror)
# predict train
# 
# use the thing!
# 
y_train['OLS'] = lm2.predict(X_train_scaled)
# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.OLS) ** (1/2)

# predict validate
y_validate['OLS'] = lm2.predict(X_validate_scaled)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.OLS) ** (1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  0.16000109453769645
# Validation/Out-of-Sample:  0.15991516704905617

# %%
#transform into dataframe. 
metric_df = metric_df.append({
    'model': 'OLS Regressor', 
    'RMSE_train': rmse_train,
    'RMSE_validate': rmse_validate,
    }, ignore_index=True)
metric_df #print the dataframe.
# Out:
#            model  RMSE_train  RMSE_validate
# 0       Baseline    0.160135       0.160054
# 1  OLS Regressor    0.160001       0.159915

# %% [markdown]
# ## Polynomial

# %%
# I decided to use polynomial for next model.
#Generate a new feature matrix consisting of all polynomial combinations 
#of the features with degree less than or equal to the specified degree.
# Polynomial provides the best approximation of the relationship between the dependent and independent variable. 
from sklearn.preprocessing import PolynomialFeatures

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree =2)

# fit and transform X_train_scaled
X_train_degree2 = pf.fit_transform(X_train_scaled)

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate_scaled)
X_test_degree2 = pf.transform(X_test_scaled)
# create the model object
lm2 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 
lm2.fit(X_train_degree2, y_train.logerror)

# predict train
y_train['polynomial'] = lm2.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.logerror, y_train.polynomial)**(1/2)

# predict validate
y_validate['polynomial'] = lm2.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.polynomial)**(1/2)

print("RMSE for Polynomial Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Polynomial Model, degrees=2
# Training/In-Sample:  0.1599376548476868
# Validation/Out-of-Sample:  0.1598879155542116

# %%
#transform result into dataframe. 
metric_df = metric_df.append({
    'model': 'polynomial', 
    'RMSE_train': rmse_train,
    'RMSE_validate': rmse_validate,
    }, ignore_index=True)
metric_df #print out the dataframe.
# Out:
#            model  RMSE_train  RMSE_validate
# 0       Baseline    0.160135       0.160054
# 1  OLS Regressor    0.160001       0.159915
# 2     polynomial    0.159938       0.159888

# %% [markdown]
# ## Decision Tree Regressor Model

# %%
from sklearn.tree import DecisionTreeRegressor
#Let's use a decision tree regressor model. 
#Decision tree regression observes features of 
#an object and trains a model in the structure of a tree to 
#predict data in the future to produce meaningful continuous output.

# %%
regressor = DecisionTreeRegressor(max_depth = 8, random_state=121)
#set the max_depth to 8. I have tried a couple, 8 performs the best.  
regressor.fit(X_train_scaled, y_train.logerror)
#fit the model
y_train['DecisionTree'] = regressor.predict(X_train_scaled)
#predict on x train scaled. 

rmse_train = mean_squared_error(y_train.logerror, y_train.DecisionTree) ** (1/2)
#get the rmse for the prediction
y_validate['DecisionTree'] = regressor.predict(X_validate_scaled)

#produce the prediction on the validate dataset. 
rmse_validate = mean_squared_error(y_validate.logerror, y_validate.DecisionTree) ** (1/2)

#print out the rmse for train and validate. 
print("RMSE for DecisionTree Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for DecisionTree Model, degrees=2
# Training/In-Sample:  0.1527284997392041
# Validation/Out-of-Sample:  0.168605691341559

# %%
#transform them into dataset. 
metric_df = metric_df.append({
    'model': 'DecisionTree', 
    'RMSE_train': rmse_train,
    'RMSE_validate': rmse_validate,
    }, ignore_index=True)
metric_df #print out the dataset.
# Out:
#            model  RMSE_train  RMSE_validate
# 0       Baseline    0.160135       0.160054
# 1  OLS Regressor    0.160001       0.159915
# 2     polynomial    0.159938       0.159888
# 3   DecisionTree    0.152728       0.168606

# %% [markdown]
# ## Random Forest Regressor Model

# %%
from sklearn.ensemble import RandomForestRegressor
#lastly, let's try random forest regressor. 
#Random forest is an ensemble learning algorithm 
#based on decision tree learners. 
#The estimator fits multiple decision trees on randomly 
#extracted subsets from the dataset and averages their prediction.

rfr = RandomForestRegressor(n_estimators=100, max_depth=7)
# To avoid overfitting, use 100 as estimators and max_depth 7. 
rfr.fit(X_train_scaled, y_train.logerror)

#fit the thing!

y_train['rfr'] = rfr.predict(X_train_scaled)
# Use the thing to predict 
rmse_train = mean_squared_error(y_train.logerror, y_train.rfr) ** (1/2)
#get the train rmse.
y_validate['rfr'] = rfr.predict(X_validate_scaled)
#predict on validate. 
rmse_validate = mean_squared_error(y_validate.logerror, y_validate['rfr']) ** (1/2)
#get the validate rmse. 
print("RMSE for  RandomForestRegressor Model, degrees=2\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for  RandomForestRegressor Model, degrees=2
# Training/In-Sample:  0.15338367796164745
# Validation/Out-of-Sample:  0.1601337956333757

# %%
#transform them into dataset. 
metric_df = metric_df.append({
    'model': 'RandomForestRegressor', 
    'RMSE_train': rmse_train,
    'RMSE_validate': rmse_validate,
    }, ignore_index=True)
#print out the dataframe. 
metric_df 
# Which model perfoms the best, has the lowest rmse?
# Out:
#                    model  RMSE_train  RMSE_validate
# 0               Baseline    0.160135       0.160054
# 1          OLS Regressor    0.160001       0.159915
# 2             polynomial    0.159938       0.159888
# 3           DecisionTree    0.152728       0.168606
# 4  RandomForestRegressor    0.153384       0.160134

# %% [markdown]
# ## Run best performing model on test, my polynomial model perform the best on the validate dataset, let's go with polynomial model on test.

# %% [markdown]
# Test the Model

# %%
# predict validate
y_test['polynomial'] = lm2.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.logerror, y_test.polynomial)**(1/2)

rmse_test
# Out:
# 0.16774104424145853

# %% [markdown]
# ## My polynomial Model on test dataset had a Root Mean Squared Error (RMSE) of 0.167.

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Key Findings

# %% [markdown]
# There is a relationship between tax_value, area, and bedroom counts in predicting the logerror of single family units. Bedrooms and tax value cluster also were shown as useful.
#
# I didn't find any feature that strongly correlate with log error.

# %% [markdown]
# # Recommendations

# %% [markdown]
# We can continue using the existing model to predict the logerror. The data suggest bedrooms, area and tax_values to be the most valued features. I recommend removing outliers from these columns to improve future modeling.

# %% [markdown]
# # Next Steps

# %% [markdown]
# With more time I would work on improving the model by adding more parameters.

# %% [markdown]
# I would like to dive deeper into the zillow database and implement feature engineering to discover the best combination of available features to predict home values.
